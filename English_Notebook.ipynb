# %% [markdown]
# * anim=life,spirit, 表示“生命，精神”等
# animal 动物；animate 使有生气，活泼；animation 生动；动画
#
# * ante-: 前面，先于
# anticipate  v. 预期 anticipation n.预期，期望
# antedate先于，早于 anterior前面的 antenna 触角；天线 antique 古董商店
# antemarital 婚前的  marriage结婚  wedding ceremony婚礼 cereal 谷类 （谷神Ceres）
# matrimony婚姻
# maternal - paternal
# engage订婚
#
# * alter,ali 表示“其他的，改变状态”
# alternate v. 交替，轮流
# alter  vt.改变，变更；改动 alternative n.替换物；取舍，抉择  alterable 可改变的
#
# * ana-表示"错误，在旁边，分开“
# analogy n. 相似，模拟，类比  analogous a.类似的  analysis v.分析  analyze v.分析
# “absence to love is what wind is to fire.”
#
# abandon v. 抛弃，放弃；n.放纵；任性=desert=discard
# acknowledge v. 承认；答谢；报偿 该词 ac-（ 去往）为古英语介词 on, knowledge 同 know（知道，了解） acknowledgment n. 承认；感谢，致谢
# We wish to acknowledge the support of the university. 我们想要感谢大学给予的支持
# be widely / generally / universally acknowledged as …
# It is a truth universally acknowledged that a single man in possession of a good fortune must be in want of a wife.
# admiration n. 欣赏
# afford v. 付得起；提供
# assemble v. 集合，聚集 as 不断+semble→不断使东西相同→组装  assembly line流水线
# VolksWagen: Beetles（Das Auto）
# alien 外国的，外来的 alienate 疏远（把别人当外国人→疏远）
# ascribe  v. 归因于，归咎于
# blame；put down to；be attributed to
# applaud v. 鼓掌；赞扬，称赞 = clap -- applause n
# applaud sb for sth
# rapturous热烈的 / enthusiastic / loud / thunderous applause
# allowance n. 津贴  monthly / annual / housing allowance   allowance for clothes
# fare 交通费 - fee专业费；salary月 - wage 小时/天/周 - payment 次；allowance 津贴；
# tips 小费; 贴士; postage 邮费；tuition 学费；stock 股票；securities 证券；
# expense开销；deposit 存款；subscription订金；down payment 定金；
# instalment 分期；scholarship 奖学金
# arrayn.陈列，一系列   ray 射线；光线
# There was a vast array of colours to choose from.有各种各样的颜色可供选择。
# assurance n.保证
# assure sb. of sth. / assure sb. that ...
# ensure sth. / that ...
# insure sth for £1,000
# insure (sth/sb) against loss / damage / theft / sickness

# %% [markdown]
# breed  v. 繁殖；培育，养育  brood（一窝；一家的孩子）的动词形式
# base v. 建立在……的基础上
# * be-使动： bewilder v. 迷惑，弄糊涂
# >* （1）beside; behind (hinder 妨碍); below; beneath; before …
# >* （2）become; because; behalf; beware; befriend; befool; belittle 小看; belie 掩盖; befall 降临发生; betray背叛（traitor 叛徒）； behave 行为；behaviorism行为主义
#
# blame n.责任
# blunder n.错误，大错
# A last-minute blunder cost them the match.最后一刻的失误使他们输掉了这场比赛。
# budget n.预算 bud + get （在萌芽时期得到的钱）

# %% [markdown]
# * cap, capt, cept ,ceive, cip, cup=take, hold, seize, 表示“拿，抓，握住”
# conceive  v. 怀孕；构思
# capacity容量，才能（拿住的能力）；capacious 宽阔的；容积大的；incapacitate 使无能；
# caption 标题;字幕（抓住主要内容→标题）captain 队长；
# capability n.能力,才能 capable 有能力的,有才能的；capacity容量;能力;
# capital 资金;首都;省会 captive俘虏；capture 捕获；cape town开普敦
# accept 接受；承认；acceptability可接受性；
# conception 概念，观念；intercept 拦截；deceive 欺骗；
# perceive 觉察；感知；receive 接受；收到；
# receipt 收据；conceit 自大；自负；
# anticipate 预料；预期的；participant 参与者；principal 主要的；首要的；
# occupy占据；occupation 职业；占有；preoccupation 全神贯注
#
# * claim, clam=cyrout, shout,表示“呼喊，叫喊"
# claim要求；声称；索赔
# clamor 喧哗；吵闹；clamorous 吵闹的
# acclaim欢呼；喝采；acclamation  喝采，称赞
# declaim朗诵；declamation 慷慨演说；雄辩
# exclaim叫喊；大声说；欢呼;exclamation 叫喊；感叹
# proclaim公布；声明；proclamation 宣告；宣言
# reclaim收回；reclamation 收复；矫正
#
# * clin, cliv=lean,slope,表示“倾斜，斜坡”
# decline   v. 下降，减少；婉拒 = turn down    reject 严词拒绝
# declination  衰退；下倾
# incline  倾向；偏向  inclination 倾向
#
# * cruc,crus,crux=cross,表示“十字形，交叉”
# cruise v. 航行，漫游 crucial 关键的；crux 难点；关键  crucify钉在十字架上；折磨
# crusade 十字军；改革运动（指中世纪十字军，佩带十字符号，引申为改革运动）
#
# * cern, cert, cret=sure, separate,表示“搞清，区别”
# concern   v. 涉及
# discern 看出；辨别；discernible 能够分辨的
# certain 肯定的；certify证明；保证；certificate 证书；执照；certitude 确信；确实
# discrete 分立的；离散的 discretion 谨慎，判断力；
# secret 秘密；secretary秘书
#
# * cid,cis=to cut,表示"切,杀"
# suicide, infanticide, regicide (regal, region), herbicide除草剂；pesticide杀虫剂；precise 精准的; concise 简洁的; scissor(s)剪刀 ...
# mater = mama → matri  Matrix 母体；矩阵  matricide 弑母
# pater = papa → patri  patricide→patriot 爱国者→patron 惠顾
# patriotism爱国主义 → Chauvinism沙文主义 性别，团体，种族，国家等 → 优越性偏见 or过分自豪感
# feminism 女权主义
# elitism精英主义 - populism民粹主义
#
# * card,cord = heart 表示“心脏，一致”
# cordial 热诚的，衷心的；record 记录（一再放在心上→记录）；
# concord 协调；协议；discord 不和；不一致；accord 一致；符合；accordion 手风琴
#
# crash v. （飞机）坠毁
# smash 打碎；粉碎；clash 碰撞声；抵触冲突（强调“撞”）；crush 压碎碾碎；splash 溅泼，
# 泼水
# conserve   v. 保护，保存
# cash  n.现金
# consolidate v. 巩固
# confront   v. 面对，面临
# comply    v. 遵守；答应    com（共同）+ply（折叠）→观点共同叠在一起→同意，遵守
# comply with 遵从 = abide by = conform to = observe = obey
# commence  v. 开始
# compensate  v. 补偿，赔偿
# coincide  v. 相同，相一致；同时发生
# collaborate  v. 合著，合作
# collide   v. 互撞，碰撞   col（一起）+lid（撞击） collide with = run into
# cling  v. 紧抓；坚守，抱紧  对称模仿自 link（链接） cling to （stick to / adhere to）

# %% [markdown]
# dazzle   v. 使眩目，耀眼
# dizzy头昏目眩的；puzzle（使）迷惑
# * duc,duct=lead,bring,表示“引导，带来”
# duct 管，导管；aqueduct 导水管 Salus Per Aquam（Health by water）水疗(SPA)
# > * educe 引出，引起; educate 教育；训练；培养 deduce 推论，演绎;introduce 介绍，引入；
# induce  v. 劝诱，诱导 reduce (往回引)降低，减少；conduct 行为；指挥；seduce 勾引；诱奸
# > * produce 生产；农产品；product 产品；productive 生产的；多产的；productivity生产力，生产活动；
#
# * dur=last,hard,表示“持久，坚硬”
# endure v. 忍受，忍耐  endurance 忍耐力
# durable 持久的；duration持续时间；during在……期间；
#
# * dia-穿过，两者之间：
# diameter 直径
# diagnosis 诊断
# diagram图表
# dialogue 对话
#
# distinction n.区分，辨别
# disguise   v. 假扮，伪装  dis（否定）+guise（装束），原指改变装束或外表，不一样的打扮，后词义贬义化。
# disguise oneself as …把某人自己伪装为
# blessing in disguise 因祸得福
# duplicate v. 复制，重复=replicate/copy   du（二）+plic（折）词源同 fold, complicate
# dominate  v. 统治，占据    来自拉丁语 domus, 家，词源同 domain（领域）
# drain   v. 渐渐耗尽 词源同 dry；brain drain 人才外流
# derive v. 得来，得到 derive enjoyment/pleasure/satisfaction from …
# descend  v. 下落 /降
# deserve   v. 值得
# deviate   v. (使)背离，(使)偏离
# defy   v. 违抗，藐视   de（去除）+fy（=fid 相信）
# defy description/analysis/belief 无法描述、分析、相信
# love defy description 爱情无法用语言描述
# dedicate  v. 奉献，献身，致力于
# deceive  v. 欺骗，哄骗 = cheat
# dense a.密集的  condense  v. 压缩，浓缩

# %% [markdown]
# * em/en- （1）包围，进入（2）使动
# embrace 拥抱=hug  brace表示手臂   bracelet 手镯
# droplet雨滴; ballet芭蕾; bullet子弹; jacket小衣服 …
# embed 安置
# embarrass 使尴尬
# encage 关押
# enchain 束缚  chain store连锁店
# entrap 诱捕
# empower 授权
# embitter 使痛苦 agony极度痛苦
# embody 体现
# embellish 美化  belle阴 / beau阳   beautify
# enact 制定，颁布
# enlist 从军，入伍 – recruit 招募
# enlighten 启发启示 - Enlightenment启蒙运动
# enchant 施魔法；使迷惑 chant 歌声歌曲 - siren(塞壬) 警报
# enclose 把…围起；附入
# encompass 围绕包围
# encounter 遇见 a chance encounter一次偶然的邂逅
# enlarge; endanger; employ; engine; encourage;
# widen; weaken; strengthen; tighten;loosen
#
# expire   v. 到期，期满
# explode 爆炸；
# exploit 开发；剥削
# enhance v. 提高，增加 来自词根 alt（高），attitude determines altitude 高度
# enhance the joy atmosphere 提高高兴的气氛 一般加抽象名词
# enroll  v. 参加；报名；注册 register 注册
# evoke  v. 引起，唤起
# emergency n.紧急情况
# encouragement n.鼓励
# essence n.本质 essential 基本的，必要的  in essence 本质上
# The essence of Arsenal’s style of football was speed.阿森纳队足球风格的精髓是强调速度。
# estimate n.估计
# make / give / provide an estimate
# a rough / approximate / accurate / conservative / official ... estimate

# %% [markdown]
# follow v. 遵从   follow the herd 人云亦云  group dynamics 群体动力
# furnish v. 配备，装饰  furniture 家具
# flap v.拍打； (鸟)振翅(飞行)  来自辅音丛 fl，拟声词。
# flaw n.裂纹，瑕疵 flaw“裂缝”，元音演变自flow（流动），有“缝”就会“流”
# fortune n.财产，大笔的钱
#
# * form=shape,表示“形状”
# formal 正式的，正规的；formalism形式主义；formality礼节；formation 形成；formula 公式；准则；formulate 公式化；制定
# conform v. 符合，遵守，适应
# deform使残废；变形；deformed 畸形的
# inform通知，告知；information 信息，情报；informative 见多识广的
# reform改革，改造
# transform 变形；改变
# uniform一致的；制服
# perform执行（任务）；表演
#
# * fl   飞行，流动/光，火
#
# > * （1）fly; flight航班; flow流动; flu; fluent; fluid 流体; flag旗帜; flavor味道; flexible; float; flood洪水; flee 逃离; flatter奉承；flaunt炫耀；flea跳蚤；fleet 舰队；flit 轻掠
#
# > * （2）flash闪光; flare强光; flame; flicker微光; flower; flint 打火石; inflammation(内火) 炎症; flashmob 快闪族（mob 暴徒）
#
# * fend/fens/flict=strike，表示“打击”
# defend v. 防守；为……辩护   defense 保卫
# offend v.冒犯，得罪 offense n.冒犯 offensive a.冒犯的
# conflict   v. 冲突，战争     afflict 使苦恼；折磨
#
# * fract=break,表示“打碎”
# fraction(整齐的)部分,一点；fragment（参差不齐的）部分
# fractional很少的；少量的 fracture 断裂；骨折
# fragile 脆的；易碎的；fragility 虚弱；脆弱
# frail脆弱的；frailty脆弱，意志薄弱
# the fragile nature of the country's infancy 这个国家新生时期的脆弱本质
# Frailty, thy name is woman! —Hamlet
#
# * fus=pour,表示“流，泻”
# fuse n.保险丝 confuse v 使混乱；使困惑
# defuse v 拆弹；缓和 diffuse v 扩散a. 弥漫散开的 effuse v 流出 infuse v 注入，灌输profuse a 丰富的；浪费的 refuse v 拒绝 suffuse v 充满；弥漫
# transfuse v 输血；倾注注入；灌输 refute v/n 反驳，驳斥（fute=fuse→反流→反驳）
#
# fashion n.方式，样子 fash=fac 做+ion→做出的东西→时髦
# be in fashion; be/go out of fashion/the lastest fashion
# in a ...fashion = in a particular way 以...方式
# Please leave the building in an orderly fashion. 请大家有秩序地离开大楼。
# She will be working out her problems in her own fashion. 她会以自己的方式来解决她的问题。

# %% [markdown]
# * grav,griev=heavy,表示“重"
# > + grieve v. 使伤心，使悲伤  grief  悲伤，心情沉重  aggrieve 使烦恼；伤心
# grievance n.牢骚，苦水
# > + grave 重大的，庄重的；坟墓  gravity 庄重；地心吸力 aggravate  加重，恶化
# from cradle to grave 一生
#
# * grad=step,grade,表示“步，级”
# grade 等级，阶级；gradual 逐步的；graduate 毕业；分级；
# degrade 降级；退化；degrading 不名誉的，可耻的；
# retrograde 退步；堕落；
# upgrade 上升，升级；downgrade 贬低，降低；
# centigrade 百分度的
# ingredient n.成分 in-（进入，使）+gred（走，层级）词源同grade, degree→走进去的，成为其中一部分的
#
# gaze v. 凝视,注视 peep偷视 peer费力的看 glame瞥视 stare怒目而视
# gear v. 使适应，使适合 来自 gear 名词含义“齿轮”
#
# guarantee n.保修单 warranty：保修单
# a two-year guarantee
# a money-back guarantee
# come with / carry a guarantee; under guarantee
#
# guilt n.犯罪 “gui”鬼→心中有鬼→“愧”
# internal restraints such as guilt, shame and embarrassment
# 来自内心的情感约束，如愧疚、羞辱和尴尬

# %% [markdown]
# * hospit/host = guest ,表示“客人”
# hospital n 医院（客气对待病人的地方）hospitality n 好客，殷勤
# hostage n 人质（把客人[留住]→人质）
# hotel n 旅馆（客人住的地方）
# hostile 敌对的；敌意的（hostility）
#
# humor n.情绪，心境
# sense of humor 幽默感；
# black humor黑色幽默（一种病态或异乎寻常的幽默）；
# ill humor 怒气；不悦
# Four Humors
# 来自希波克拉底的体液理论。他是古希腊著名的医生，认为体液即是人体性质的物质基础。
# 人体中有四种性质不同的液体，它们来自于不同的器官。其中，粘液生于脑，是水根，有冷
# 的性质；黄胆汁生于肝，是气根，有热的性质；黑胆汁生于胃，是土根，有渐温的性质；血
# 液出于心脏，是火根，有干燥的性质。人的体质不同，是由于四种体液的不同比例所致。
# 血液：blood -sanguine 乐观的；红润的
# 粘液：phlegm -phlegmatic 冷淡冷漠的
# 胆液：choler -choleric 易怒的；melancholy忧郁
# 黑胆汁：black bile -bilious 胆汁的；坏脾气的
#
# hamper  v. 妨碍，限制；n.有盖篮子 来自古法语 hanap（杯子，酒杯），后引申词义装杯子的大篮子。等同于习语 basket case（精神失常的人；经济困顿的国家）。
# hamper traffic 阻碍交通；deluxe hamper 豪华礼篮
#
# haul  v.(拖,拉)来自中古英语 halen（拉升，抬高），原指航海时升帆，引申词义水手升帆时喊的号子。
# haul sb off 强迫去某处；haul sb up (法庭上的)传讯
# see/turn/lay/start/pay + off
#
# hind（后面的），引申词义“拉后腿”
# hinder  v. 阻碍，妨害  = get in the way of
#
# hoist  v. 举起，升起，吊起；n.起重机
# be hoist with/by your own petard（爆竹） 搬起石头砸自己的脚
#
# harmony n.与......协调一致，和谐
# an era of peace and harmony 和平共处的时代
# be in harmony with sth
# the harmony of sea and sky 海天一色
# 来自于希腊神话中的和谐女神Harmonia；在罗马神话中对应的神祇为Concordia。
# Harmonia的对头是不和女神厄里斯。根据赫西俄德的《神谱》，她是战神阿瑞斯和爱神阿芙洛狄忒私通所生的女儿。

# %% [markdown]
# * inter-  在…之间，相互
# interpret  v. 解释，说明；口译 inter-（在内，在中间，相互）+pret（价值交换），引申词义“中介，协商者，谈判者” 。
# > * interior 内部（的）；internal 内部的 ;external 外部的
# international；internet
# interpersonal 人际的
# interpose 置于，介入 intervene 干涉
# interact 互动 interaction 相互影响
# interchange 互换 interrelate 相互关联
# > * interview 采访；面试 interviewer 面试官 interviewee 面试者
# employer 雇主 employee 雇员 trainer 教官 trainee 学员
#
# * integr = whole "完整"
# integral a完整的 integrate v使一体，使结合 integrity n.正直，诚实
# disintegrate v 使瓦解，分裂
#
# identify  v.认出,确认 identity身份 identification 鉴定,识别 distinguish 区分(在2者以上)
#
# ignite  v. 引燃  来自拉丁语 ignis(火),词源同Egni，印度火神。 spark 火花
#
# immerse  v. 使浸没   im（进入，使）+mers（浸入）
# immerse oneself in 潜心专注于某事
# impose  v. 把……强加于
# impose ban / tax / burden / moral values / belief …  on sb
# 强加一个禁令/税赋/负担/价值观/信仰 给某人
#
# indulge  v. 纵容，放任  回构自 indulgence（爱好，纵容）
# in（进入，使）+dulge（长的，长时间的），其原义为长时间从事于某事。
# indulge in self-pity 沉浸于自怨自艾
#
# insight n.理解，洞察力
# This cartoon gives us a real insight into ...
# ... provide new insights into ...
# a woman of great insight 一位极有眼光的妇女
#
# inspection n.检查，视察
# tour of inspection  巡视；巡查
# quality inspection; inspection system; commodity inspection
#
# instinct n.本能，直觉
# intuition; sexual / maternal / survival instinct
# sb’s first instinct 第一感觉
#
# intend  v. 意欲 intend to do = want to do
# intuition n.直觉
# Use your intuition here: if you really feel that you should do it now, then follow your instinct.
#
# illusion n.错觉，假象 il（进入，使动）+lus（玩乐，玩耍）
# distinguish between illusion and reality

# %% [markdown]
# jeopardize  v. 危及，损坏  来自古法语 jeu parti（一种机会平等的赌博游戏），引申词义危险，风险。
# jeopardy 危害；  in jeopardy；   put/place sth in jeopardy
# jeopardize health / public security / social order / peace process

# %% [markdown]
# * loc=place,表示“地方”
# locate   v. 位于；定位
# local 当地的；地方的；局部的；locality 所在地；locate 坐落，位于；location 位置；地点；
# allocate 分配，部署；collocate 并列；排列；relocate 重新定位
#
# * limin,lim=threshold，表示“门槛，限制”
# limit 限制  limitation n.局限性，缺点 delimit 定界限
# preliminary  预备的；初步的 eliminate v. 消除
#
# * log,logu=speak,表示“说话”
# logic 逻辑（学）（说话的学问→逻辑学）；logical符合逻辑的；analogy 类比；类似；apology
# 道歉，认错；apologize 道歉；prologue开场白；loquacious 爱说话的；colloquial 口语的
#
# * lect,leg=speak,read,表示“讲，读”
# allege v. 断言，宣称
# lecture 讲课，讲座
# dialect 方言（dia 在…之间+lect→在一部分人之间说→方言）
# legible 可读的，易读的；illegible 难读的
# legend 传奇；图例；legendary传奇的，像传奇一样的
#
# * leg,legis=law,表示“法律”
# legal 法律的；合法的；illegal 不合法的；
# delegate 代表；
# legislate 立法；legislature 立法机关；legislation n.立法，法律
#
# lease n.租约，契约 来自拉丁语 lasso（松开，放手）
#
# linger   v.  徘徊，留恋；迟缓，拖延 来自古英语 lengan（延长，加长）。
#
# loyalty n.忠诚，忠心
# luxury n.奢侈，豪华

# %% [markdown]
# * magn 大：
# magnify   v. 放大；夸大
# magnanimous 心胸博大的（magnanimity）； magnate 巨头，权贵；magnificence 庄严，宏大；magnitude宏伟，震级
# * mini,min=small,表示“小”
# mingle v. 混合起来,相混合 来自古英语 mengan(揉,捏)形成揉在一起,引申词义“融合，混合”
# minimize  v. 最小化
# minister 部长；大臣（古代大臣称自己是"小人") administer 管理，治理；administration 行政，管理
# minim 微量，小量
# minor 较小较少的；次要的；辅修；未成年人
# minority少数；少数民族 ；minus 减去
# minute 微小的，细微的；一分钟
# * mon,  monit=  warn,表示“警告”
# monitor  v. 检测，监测
# monitor 监视器；班长；admonish 训诫，警告；summon (命令性)召集；summons 传票，传唤；
# monument 纪念碑（monu 警告，提醒+ment→提醒的东西→纪念碑）

# %% [markdown]
# * neg=deny, 表示“否认”
# deny   v. 否认
# neglect   v. 忽视；疏忽

# %% [markdown]
# * over 过度/在……之上
# > + (1)overtime 超时的；加班；overstudy用功过度；overwork 过度劳累；overact 表演过火；overdose 药物过量；overproduction 生产过度；overcorrect 矫枉过正的；overcrowded 挤满的
# > + (2)overall 全面的；工作服；overcoat外套；overcome 战胜，克服；overlook俯视；疏忽；overnight 通宵的；一夜功夫；overpass胜过；天桥；overseas 外国的；在海外；overtake 追上；超车；overturn=overthrow 推翻
#
# occupy   v. 占据；占用时间 oc（向前，朝向）+cup(抓,握,持有),即“抓住的,占有的” 。
# occupy sb with (doing) sth
#
# oppress   v. 压迫  op（在上，表强调）+ press（压，按，逼迫）。引申词义压制，压迫。
# originate  v. 首创，起源  origin；original
# overlap   v. 部分重叠  over（在上）+ lap（折叠）；laptop – desktop
# overwhelm  v. 压倒，浸没，使不安  over（在上，超过）+ whelm（淹没）

# %% [markdown]
# parade   v. 游行 来自拉丁语 parere（准备，安排），原指接受检阅的军队。
# military parade 阅兵   hit parade 流行音乐排行榜
#
# permeate  v. 渗入，渗透  per（通过）+meare（改变，交换）
# Racism continues to permeate our society. 在我们的社会里，种族主义依然无处不在。
# An emotional intensity permeates every one of her songs. 她的每一首歌都饱含着强烈的感情。
#
# prescribe  v. 处方，开药
#
# * pro(往前/很多/赞同)
# prolong v. 延长，拖延
# lengthen 延长; drag on / out拖延; procrastination拖延症
# promise  v. 许诺
# propel  v. 推进，推动 repel 击退（敌人），使…反感；
# protest  v. 抗议，反对
# provoke  v. 引起，激怒  pro（前面）+voke（喊叫）→到别人面前喊→激怒
#
# * pel/puls= drive,  push, 表示“驱动，推”
# compel 强迫；compelling 强制的；激发兴趣的；expel 开除，驱逐；impel 推进，驱动；dispel
# 驱散；消除；compulsion 强制；compulsory 强制性的；pulse脉搏；impulse 冲动，刺激；
# impulsive 冲动的
#
# * plor=cry，weep,  表示“喊，哭”
# deplore悲叹，痛惜  implore 乞求，恳求  explore v. 探险，探索
#
# * priv=single,  alone,  表示“单个”
# deprive v. 剥夺 + sb + of + sth
# private 私人的   privacy隐私（priv+acy)   privilege 特权
#
# * ple,plen,plet, pli=full, fill,表示“满，填满”
# implement n.工具 v. 实施；supplement 增补，补充；
# plenty 大量，丰富；replenish 再装满；
# complete 完全的；   complement  v. 补充
# accomplish 成就；完成；compliment 赞扬，恭维
#
# * pend,pens,pond表示“称重量”，引申为“花费”
# expend 花费（expensive昂贵的）；expenditure n.开支
# huge cuts in public expenditure 大幅削减公共开支
# government expenditure on education 政府的教育开支
# revenue and expenditure 收支
# pension 养老金；抚恤金；compensate补偿；赔偿；
# dispense分配，分送；dispensable可分配的；不必要的；indispensable不可缺少的；
# ponder考虑；沉思；ponderous笨重的；笨拙的；呆板的

# %% [markdown]
# * quest,quir, quis, quer= seek,  search,  表示“寻求，询问”
# acquaint v. 熟悉，认识 make acquaintance with 结识  nodding acquaintance 点头之交
# quest 探求，寻找；question 疑问；request 婉言要求，恳请；demand 强烈要求
# acquire v.获取；acquirement 获得，学识；acquired后天习得的；
# inquire 盘问，追究；inquisition 调查，审问；require一般请求，命令；
# prerequisite 先决条件；conquer v.征服；conquest n.征服

# %% [markdown]
# rad（辐射，放射）+ate（动词后缀），引申词义“流露自信，容光焕发”。
# radiate  v. 辐射；从中心向各方伸展出
# radiance 容光焕发   radiant 放射的，容光焕发的  radiator 暖气片，散热器
# rad 拉德（辐射吸收剂量单位）
#
# reconcile v. 使和好，调解  re（再，重新）+concil（和解），词源同 conciliation（调解；安抚）
# refresh  v. 刷新；提神，使清新   re（再，重新）+fresh（新鲜的，有活力的）。
# refute  v. 反驳，驳斥   re 往回+fute（=fuse）→反流→反驳
# refute a hypothesis 假说 / claim论断 / idea
# remain  v. 停留，依旧是
# 系动词：Please remain seated until all the lights are on.
# remain unchanged / silent / friends / unclear …
# man，main=stay，表示“逗留”
# permanent  持久的，永恒的 permanence 永恒，持久
# remain 剩余，遗留；遗迹；剩余物
#
# repel  v. 抗御，抵拒
# rescue  v. 营救，救援  来自拉丁语 re（往回）+ excutere（摇出）
# resign  v. 辞职  re（再）+sign（签字）
# resort  v. 求助，凭借，诉诸；度假胜地  re（往回，再）+sortir（出去）
# resume  v. 重新开始，继续
# résumé简历；curriculum vitae
# revenge  v. 报仇，报复   re（表强调）+veng（复仇）词源同 avenge（报复）；vengeance（复仇）。

# %% [markdown]
# * sid=sit,表示“坐”
# preside   v. 主持  president 总统；校长；董事长
# reside 居住 residence 居住；住宅
# consider  考虑 considerate 考虑周到的；体贴的 considerable 相当大的；重要的
# take sth into consideration / account
# a considerable proportion of
# assiduous 勤勉的，刻苦的
#
# * sign=mark,表示“记号，信号”
# signal 信号；signalize 通知；发信号；signature签名；盖章；
# assign 分配；指定；assignment 分配;任务；
# signify表示；象征；significance 重要；意义；
# design计划；设计；resign 辞职；放弃
#
# * scend, scens, scent=climb,表示“爬，攀”
# ascend v.攀登；上升
# descend下降；传下
# transcend 超越，胜过
# descendant 子孙；后代
#
# * sting,stinct,stimul=priek 表示“刺，刺激”来自extinguish 熄灭→灭绝的
# extinction n.灭绝  species in danger of extinction 有灭绝危险的物种
# on the verge / edge / brink of extinction 濒临灭绝
# face extinction / be threatened with extinction
# Their traditional way of life seems doomed to extinction
#
# scan  v. 扫描；细察，审视，查找   scanning + skimming + detailed reading
# scrape  v. 剥下，刮下
# Other options to restore the frescoes would have required using chemicals to remove the unwanted
# layer or using physical means to scrape it off.  其他修复壁画的方法则需要用化学药品来除去
# 那些多余的覆盖层，或者用物理方法将其刮落。
# scratch  v. 抓，搔
# scratch the surface仅触及问题的表面
# start from scratch 白手起家
#
# shrink   v. 收缩，减少
# ink; drink; stink … The city continued to shrink.
# shrink from 退避；在…前面畏缩
# shrink into oneself 缩成一团；变得沉默
#
# standardize  v. 使标准化
# standardized tests 标准化测试
#
# steer   v. 驾驶，引导
# steer sb towards/away from/through sth Teachers try to steer pupils away from drugs.
#
# strengthen  v. 加强，使更强壮
# strengthen revolve 决心/ties/bonds/links 联系 / communication 交流 / supervision 监管 …
#
# stretch   v. 伸展
# stretch out 躺下休息；伸出（手脚等）
# subscribe  v. 预订，订阅
# suck   v. （用嘴）吸，吞噬，卷入 来自古英语 sucian（吮吸），词源同 soak（浸泡；吸入），soup。
# They just want to suck on our blood.他们只是想吸我们的血而已。
# suppress  v. 镇压；抑制
# suppress uprising 镇压起义；suppress evidence隐瞒证据；suppress anger 强压怒火
#
# sustain   v. 维持；承受
# sustain interest 保持兴趣
# sustain relationship 维持关系
# sustain economic growth 保持经济增长
# sustain injury / damage / financial losses

# %% [markdown]
# * termin=limit ，表示“界限”
# terminate  v. 终止，结束 terminal 终结的 n.终端
# termination 结束；终止 terminology 术语，专门名词（定出界限的学科→下定义→术语）
# * tribut=give，表示“给予”
# tribe 氏族，部落（three beings）
# tribute 贡品  contribute 捐赠；贡献 attribute v. 归因于 n.属性
# distribute 分配；分发 retribution 惩罚；报答；报复
# determine 限定；决定  determined 决定了的；坚定的
#
# tackle  v. 解决，处理；n.装备 来自中古荷兰语 takel（船帆，索具）来自 taken（抓住，拿到）
# tackle the problem = handle = cope with = deal with
#
# tempt  v. 引诱，劝诱 来自拉丁语 temptare（尝试，试探），改写自 tentare（接触，尝试），词源同 tentative（企图），tentacle（触手）助记：tempt 里有empty，色即是空
#
# test=test，表示“测试，证据”
# testify 表明；证实（test+ify→用证据证明）
# testimony 证据；证词（testi+mony表状态或物品）
# attest 证明（at一再+test 证据）
# contest 比赛，竞赛  contestant 竞争者；选手 = competitor
# detest 嫌恶，憎恶（de 不+test→不愿作证→嫌恶）
# testament 遗嘱；圣约
#
# transmit  v. 传播，传递

# %% [markdown]
# * ver=true，表示“真实”
# verify  v. 证实，证明
# verity 真实；重要的真理；verify 核实，证实 verdict 裁决
# 哈佛校训：Amicus Plato, Amicus Aristotle, Sed Magis Amicus VERITAS. 与柏拉图为友，与亚
# 里士多德为友，更要与真理为友。
# * vi,via,voy =way， 表示“道路”
# convey   v. 表达，传达
# * voc，vok=call, voice，表示“叫喊，声音”
# advocate n.拥护者，提倡者
# vocal 声音的；vocation 职业；vocabulary词汇；evoke 唤醒唤起；provoke触怒；煽动
#
# view  v. 视为，看做
# view … as …
# view … from … perspective / standpoint
# view … with caution / suspicion / skepticism

# %% [markdown]
# wreck  v. (船只)失事
# 来自 wreg（推，转，扭曲），词源指“扭曲的物体”，主要用于指船的残骸，失事的船只等。

# %% [markdown]
# Bible Romans: We also glory in tribulations, knowing that tribulation produces perseverance; and perseverance, character; and character, hope.
